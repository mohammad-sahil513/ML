# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.metrics import confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import os
import matplotlib.image as mpimg
import pandas as pd

# %%
#!rm -r results

# %%
def get_data(dataset_name):

    if dataset_name=='cifar10':
        (train_images, train_labels), (test_images, test_labels)= tf.keras.datasets.cifar10.load_data()

        images= np.concatenate([train_images, test_images], axis=0)
        labels= np.concatenate([train_labels, test_labels], axis=0)

        print(images.shape, labels.shape)
        return images, labels

    else:
        (train_images, train_labels), (test_images, test_labels)= tf.keras.datasets.mnist.load_data()

        images= np.concatenate([train_images, test_images], axis=0)
        labels= np.concatenate([train_labels, test_labels], axis=0)

        print(images.shape, labels.shape)
        return images, labels

# %%
def plot_plots(dataset_name, path):
    plot_dir= path

    img_plots= [f for f in os.listdir(plot_dir) if f.startswith(dataset_name) and f.endswith(('.png', '.jpg'))]

    for img_file in img_plots:
        img_path= os.path.join(plot_dir, img_file)
        img= mpimg.imread(img_path)
        plt.figure(figsize= (8, 6))
        plt.imshow(img)
        plt.axis('off')
        plt.show()

# %%
def get_image_augmentation():
  train_datagen = ImageDataGenerator(
        rotation_range=20,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest',
        rescale= 1./255
    )

  test_datagen= ImageDataGenerator(rescale= 1./255)

  return train_datagen, test_datagen

# %%
def get_image_augmentation():
  train_datagen = ImageDataGenerator(
        rotation_range=20,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        fill_mode='nearest',
        rescale= 1./255
    )

  test_datagen= ImageDataGenerator(rescale= 1./255)

  return train_datagen, test_datagen

# %%
if not os.path.exists('results'):
  os.mkdir('results')
if not os.path.exists('results/plots'):
  os.mkdir('results/plots')

# all plotting stuff will be here !!
def plot_history(history, name):
    plt.figure(figsize=(10,4))
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label='train_acc')
    plt.plot(history.history['val_accuracy'], label='val_acc')
    plt.legend(); plt.title(f'Accuracy for {name}')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(); plt.title(f'Loss for {name}')
    plt.savefig(f'results/plots/{name}_history.png')
    plt.close()


def plot_confusion(y_true, y_pred, name):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8,6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title(f'Confusion Matrix for {name}')
    plt.savefig(f'results/plots/{name}_confusion.png')
    plt.close()


def plot_roc_auc(y_true, y_score, n_classes, name):
    # y_true: integer labels; y_score: probs
    y_true_bin = label_binarize(y_true, classes=list(range(n_classes)))
    fpr = dict(); tpr = dict(); roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_score[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # micro-average
    fpr['micro'], tpr['micro'], _ = roc_curve(y_true_bin.ravel(), y_score.ravel())
    roc_auc['micro'] = auc(fpr['micro'], tpr['micro'])

    plt.figure(figsize=(8,6))
    for i in range(n_classes):
        plt.plot(fpr[i], tpr[i], lw=1, label=f'class {i} (AUC={roc_auc[i]:.2f})')
    plt.plot([0,1],[0,1],'k--')
    plt.xlabel('FPR')
    plt.ylabel('TPR')
    plt.title(f'ROC curves for {name}')
    plt.legend(loc='lower right')
    plt.savefig(f'results/plots/{name}_roc.png')
    plt.close()

# %%
# this is for both mnist and cifar
def simple_cnn(input_shape, classes= 10):
  model= tf.keras.models.Sequential(
    [
       tf.keras.layers.Conv2D(64, (3, 3), activation="relu",padding="same", input_shape= input_shape),
       tf.keras.layers.BatchNormalization(),
       tf.keras.layers.MaxPool2D(2, strides=2, padding="valid"),
       tf.keras.layers.Conv2D(128, (3, 3), activation="relu", padding="same"),
       tf.keras.layers.BatchNormalization(),
       tf.keras.layers.MaxPooling2D(2, strides= 2, padding="valid"),
       tf.keras.layers.Dropout(0.2),

       tf.keras.layers.Conv2D(256, (3, 3), activation= "relu", padding="same"),
       tf.keras.layers.BatchNormalization(),
       tf.keras.layers.Conv2D(256, (3, 3), activation= "relu", padding="same"),
       tf.keras.layers.BatchNormalization(),
       tf.keras.layers.MaxPooling2D(2, strides= 2, padding="valid"),
       tf.keras.layers.Dropout(0.2),

       tf.keras.layers.Conv2D(512, (3, 3), activation= "relu", padding="same"),
       tf.keras.layers.BatchNormalization(),
       tf.keras.layers.Conv2D(512, (3, 3), activation= "relu", padding="same"),
       tf.keras.layers.BatchNormalization(),
       tf.keras.layers.MaxPooling2D(2, strides= 2, padding="valid"),
       tf.keras.layers.Dropout(0.3),

       tf.keras.layers.Flatten(),
       tf.keras.layers.Dense(256, activation="relu"),
       tf.keras.layers.Dropout(0.3),
       tf.keras.layers.Dense(128, activation="relu"),
       tf.keras.layers.Dense(classes, activation="softmax")
    ]
  )
  return model

def build_vgg_cifar(input_shape, num_classes, freeze_base=True):
    base = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)
    if freeze_base:
        base.trainable = False

    for layer in base.layers[-10:]:
        layer.trainable=True
    model= tf.keras.models.Sequential(
        [
          tf.keras.layers.RandomFlip("horizontal"),
          tf.keras.layers.RandomRotation(0.1),
          tf.keras.layers.Resizing(224, 224),
          tf.keras.layers.Rescaling(1./255),
          #preprocess_input,
          base,
          tf.keras.layers.GlobalAveragePooling2D(),
          tf.keras.layers.Dense(256, activation='relu'),
          tf.keras.layers.Dropout(0.5),
          tf.keras.layers.Dense(num_classes, activation='softmax')
        ])
    return model

# this is for mnist dataset
def build_vgg16_transfer(input_shape, num_classes, freeze_base=True):
    base = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)
    if freeze_base:
        base.trainable = False
    model= tf.keras.models.Sequential(
        [
          tf.keras.layers.RandomFlip("horizontal"),
          tf.keras.layers.RandomRotation(0.1),
          tf.keras.layers.Resizing(224, 224),
          tf.keras.layers.Rescaling(1./255),
          #preprocess_input,
          base,
          tf.keras.layers.GlobalAveragePooling2D(),
          tf.keras.layers.Dense(256, activation='relu'),
          tf.keras.layers.Dropout(0.5),
          tf.keras.layers.Dense(num_classes, activation='softmax')
        ])
    return model


def build_alexnet(input_shape, num_classes):
    # A Keras-style AlexNet (simplified)

    inp= tf.keras.layers.Input(shape=[None, None, 3])
    x = tf.keras.layers.RandomFlip("horizontal")(inp)
    x = tf.keras.layers.RandomRotation(0.1)(x)
    x = tf.keras.layers.Resizing(224, 224)(x)
    x = tf.keras.layers.Rescaling(1./255)(x)
    x = tf.keras.layers.Conv2D(96, (11,11), strides=4, activation='relu', padding='same')(x)
    x = tf.keras.layers.MaxPooling2D((3,3), strides=2)(x)
    x = tf.keras.layers.Conv2D(256, (5,5), activation='relu', padding='same')(x)
    x = tf.keras.layers.MaxPooling2D((3,3), strides=2)(x)
    x = tf.keras.layers.Conv2D(384, (3,3), activation='relu', padding='same')(x)
    x = tf.keras.layers.Conv2D(384, (3,3), activation='relu', padding='same')(x)
    x = tf.keras.layers.Conv2D(256, (3,3), activation='relu', padding='same')(x)
    x = tf.keras.layers.MaxPooling2D((3,3), strides=2)(x)
    x = tf.keras.layers.Flatten()(x)
    x = tf.keras.layers.Dense(4096, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    x = tf.keras.layers.Dense(4096, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    out = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inp, out)
    return model


def inception_module(x, filters):
    # filters: tuple/list (f1, f3r, f3, f5r, f5, poolproj)
    f1, f3r, f3, f5r, f5, poolproj = filters
    path1 = tf.keras.layers.Conv2D(f1, (1,1), padding='same', activation='relu')(x)
    path2 = tf.keras.layers.Conv2D(f3r, (1,1), padding='same', activation='relu')(x)
    path2 = tf.keras.layers.Conv2D(f3, (3,3), padding='same', activation='relu')(path2)
    path3 = tf.keras.layers.Conv2D(f5r, (1,1), padding='same', activation='relu')(x)
    path3 = tf.keras.layers.Conv2D(f5, (5,5), padding='same', activation='relu')(path3)
    path4 = tf.keras.layers.MaxPooling2D((3,3), strides=1, padding='same')(x)
    path4 = tf.keras.layers.Conv2D(poolproj, (1,1), padding='same', activation='relu')(path4)
    return tf.keras.layers.concatenate([path1, path2, path3, path4], axis=-1)


def build_googlenet_like(input_shape, num_classes):

    inp = tf.keras.layers.Input(shape=[None, None, 3])
    x = tf.keras.layers.RandomFlip("horizontal")(inp)
    x = tf.keras.layers.RandomRotation(0.1)(x)
    x = tf.keras.layers.Resizing(224, 224)(x)
    x = tf.keras.layers.Rescaling(1./255)(x)
    x = tf.keras.layers.Conv2D(64, (7,7), strides=2, padding='same', activation='relu')(x)
    x = tf.keras.layers.MaxPooling2D((3,3), strides=2, padding='same')(x)
    x = tf.keras.layers.Conv2D(64, (1,1), activation='relu')(x)
    x = tf.keras.layers.Conv2D(192, (3,3), padding='same', activation='relu')(x)
    x = tf.keras.layers.MaxPooling2D((3,3), strides=2, padding='same')(x)
    # a few inception modules (small)
    x = inception_module(x, (64, 96, 128, 16, 32, 32))
    x = inception_module(x, (128, 128, 192, 32, 96, 64))
    x = tf.keras.layers.MaxPooling2D((3,3), strides=2, padding='same')(x)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.5)(x)
    out = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

    model= models.Model(inp, out)
    return model


def build_rnn_for_images(input_shape, num_classes):
    # Treat each row as a timestep sequence of pixels (flatten channels)
    timesteps = input_shape[0]
    features = input_shape[1] * input_shape[2]
    inp = tf.keras.layers.Input(shape=input_shape)
    x = tf.keras.layers.Reshape((timesteps, features))(inp)
    x = tf.keras.layers.GRU(256, return_sequences=False)(x)
    x = tf.keras.layers.Dense(128, activation='relu')(x)
    out = tf.keras.layers.Dense(num_classes, activation='softmax')(x)
    model = models.Model(inp, out)
    return model

# %%
model_type= {
    "VGG16": build_vgg16_transfer,
    "AlexNet": build_alexnet,
    "GoogLeNet": build_googlenet_like,
    "RNN": build_rnn_for_images,
    "CNN": simple_cnn

}

# %%
class StopAtAccuracy(tf.keras.callbacks.Callback):
    """
    Callback to stop training when the desired accuracy is reached.
    """
    def __init__(self, target_accuracy=0.90):
        super(StopAtAccuracy, self).__init__()
        self.target_accuracy = target_accuracy

    def on_epoch_end(self, epoch, logs=None):
        current_accuracy = logs.get('accuracy')

        if current_accuracy is not None and current_accuracy >= self.target_accuracy:
            print(f"\n\nReached {self.target_accuracy*100:.0f}% accuracy. Training cancelled at epoch {epoch + 1}.")
            self.model.stop_training = True

# %%
def run_experiment(dataset_name):
    splits= [0.8, 0.9]
    results= []

    images, labels= get_data(dataset_name)
    for split in splits:
        train_images, test_images, train_labels, test_labels= train_test_split(images, labels, train_size= split, random_state= 42)

        for m in model_type:
            plot_name_prefix= f'{dataset_name}_{m}_{split}'
            if m in ["CNN", 'RNN']:
                train_datagen, test_datagen= get_image_augmentation()

                train_datagen.fit(train_images)
                test_datagen.fit(test_images)

                tf.keras.backend.clear_session()
                if dataset_name=='mnist':
                    model= model_type[m]((28, 28, 1), 10)
                else:
                    model= model_type[m]((32, 32, 3), 10)

                model.compile(
                    optimizer= tf.keras.optimizers.Adam(1e-4),
                    loss='sparse_categorical_crossentropy',
                    metrics= ['accuracy']
                )

                print(f'Training starting for {m} with split- {split}')
                history= model.fit(
                    train_datagen.flow(train_images, train_labels),
                    epochs= 15,
                    validation_data= test_datagen.flow(test_images, test_labels),
                    callbacks= [
                        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1),
                        EarlyStopping(monitor='val_loss', patience=8, verbose=1),
                        StopAtAccuracy(0.91)
                    ]
                )

                plot_history(history, plot_name_prefix)
                plot_confusion(test_labels, np.argmax(model.predict(test_images), axis=1), plot_name_prefix)
                plot_roc_auc(test_labels, model.predict(test_images), 10, plot_name_prefix)

            elif m=='VGG16':
                if dataset_name=='mnist':
                    train_images_rgb = np.repeat(train_images, 3, axis=-1)
                    test_images_rgb = np.repeat(test_images, 3, axis=-1)
                else:
                    train_images_rgb= train_images
                    test_images_rgb= test_images

                train_images_processed= preprocess_input(train_images_rgb)
                test_images_processed= preprocess_input(test_images_rgb)

                tf.keras.backend.clear_session()
                if dataset_name=='mnist':
                    model= model_type[m]((224, 224, 3), 10)
                else:
                    model= build_vgg_cifar((224, 224, 3), 10)

                model.compile(
                    optimizer= tf.keras.optimizers.Adam(1e-4),
                    loss= 'sparse_categorical_crossentropy',
                    metrics= ['accuracy']
                )

                print(f'Training starting for {m} with split- {split}')

                history= model.fit(
                    train_images_processed, train_labels,
                    epochs= 20,
                    validation_data= (test_images_processed, test_labels),
                    callbacks= [
                        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1),
                        EarlyStopping(monitor='val_loss', patience=8, verbose=1),
                        StopAtAccuracy(0.91)

                        ]
                )
                plot_history(history, plot_name_prefix)
                plot_confusion(test_labels, np.argmax(model.predict(test_images_processed), axis=1), plot_name_prefix)
                plot_roc_auc(test_labels, model.predict(test_images_processed), 10, plot_name_prefix)

            else:
                if dataset_name=='mnist':
                    train_images_rgb = np.repeat(train_images, 3, axis=-1)
                    test_images_rgb = np.repeat(test_images, 3, axis=-1)

                else:
                    train_imagess_rgb= train_images
                    test_images_rgb= test_images

                tf.keras.backend.clear_session()
                model= model_type[m]((224, 224, 3), 10)
                model.compile(
                    optimizer= tf.keras.optimizers.Adam(1e-4),
                    loss= 'sparse_categorical_crossentropy',
                    metrics= ['accuracy']
                )

                print(f'Training starting for {m} with split- {split}')
                history= model.fit(
                    train_images_rgb, train_labels,
                    epochs= 20,
                    validation_data= (test_images_rgb, test_labels),
                    callbacks= [
                        ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1),
                        EarlyStopping(monitor='val_loss', patience=8, verbose=1),
                        StopAtAccuracy(0.91)
                ])

                plot_history(history, plot_name_prefix)
                plot_confusion(test_labels, np.argmax(model.predict(test_images_rgb), axis=1), plot_name_prefix)
                plot_roc_auc(test_labels, model.predict(test_images_rgb), 10, plot_name_prefix)

            print(f'Logged the training metrics...')
            results.append({
                "DatasetName": dataset_name,
                "Model": m,
                "Split": split,
                "Accuracy": history.history['accuracy'][-1],
                "Val_Accuracy": history.history['val_accuracy'][-1],
            })
    results= pd.DataFrame(results)
    results.to_csv(f'results/{dataset_name}_results.csv', index=False)
    return results

# %%
# %%time
df_cifar= run_experiment('cifar10')
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# (60000, 32, 32, 3) (60000, 1)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Training starting for VGG16 with split- 0.8
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 389s 252ms/step - accuracy: 0.2692 - loss: 1.9400 - val_accuracy: 0.6459 - val_loss: 1.0029 - learning_rate: 1.0000e-04
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 386s 257ms/step - accuracy: 0.6359 - loss: 1.0421 - val_accuracy: 0.7640 - val_loss: 0.6871 - learning_rate: 1.0000e-04
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 386s 257ms/step - accuracy: 0.7294 - loss: 0.7847 - val_accuracy: 0.8023 - val_loss: 0.5664 - learning_rate: 1.0000e-04
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 385s 257ms/step - accuracy: 0.7843 - loss: 0.6426 - val_accuracy: 0.8257 - val_loss: 0.5397 - learning_rate: 1.0000e-04
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 385s 257ms/step - accuracy: 0.8162 - loss: 0.5480 - val_accuracy: 0.8488 - val_loss: 0.4489 - learning_rate: 1.0000e-04
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 385s 257ms/step - accuracy: 0.8384 - loss: 0.4824 - val_accuracy: 0.8567 - val_loss: 0.4264 - learning_rate: 1.0000e-04
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 385s 257ms/step - accuracy: 0.8547 - loss: 0.4379 - val_accuracy: 0.8588 - val_loss: 0.4355 - learning_rate: 1.0000e-04
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 386s 257ms/step - accuracy: 0.8667 - loss: 0.3954 - val_accuracy: 0.8765 - val_loss: 0.3758 - learning_rate: 1.0000e-04
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 386s 257ms/step - accuracy: 0.8750 - loss: 0.3695 - val_accuracy: 0.8625 - val_loss: 0.4445 - learning_rate: 1.0000e-04
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 386s 257ms/step - accuracy: 0.8882 - loss: 0.3310 - val_accuracy: 0.8582 - val_loss: 0.4499 - learning_rate: 1.0000e-04
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8986 - loss: 0.3031
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 386s 257ms/step - accuracy: 0.8986 - loss: 0.3031 - val_accuracy: 0.8848 - val_loss: 0.3770 - learning_rate: 1.0000e-04
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - accuracy: 0.9247 - loss: 0.2234
#
# Reached 91% accuracy. Training cancelled at epoch 12.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 386s 257ms/step - accuracy: 0.9247 - loss: 0.2234 - val_accuracy: 0.9013 - val_loss: 0.3132 - learning_rate: 5.0000e-05
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 46s 123ms/step
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 46s 123ms/step
# Logged the training metrics...
# Training starting for AlexNet with split- 0.8
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 106s 68ms/step - accuracy: 0.2643 - loss: 1.9623 - val_accuracy: 0.5065 - val_loss: 1.3563 - learning_rate: 1.0000e-04
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 102s 68ms/step - accuracy: 0.5137 - loss: 1.3510 - val_accuracy: 0.6169 - val_loss: 1.0620 - learning_rate: 1.0000e-04
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 103s 68ms/step - accuracy: 0.6090 - loss: 1.1034 - val_accuracy: 0.6827 - val_loss: 0.8942 - learning_rate: 1.0000e-04
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 103s 69ms/step - accuracy: 0.6677 - loss: 0.9436 - val_accuracy: 0.7119 - val_loss: 0.8147 - learning_rate: 1.0000e-04
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 103s 69ms/step - accuracy: 0.7068 - loss: 0.8452 - val_accuracy: 0.7412 - val_loss: 0.7490 - learning_rate: 1.0000e-04
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 102s 68ms/step - accuracy: 0.7327 - loss: 0.7622 - val_accuracy: 0.7534 - val_loss: 0.7270 - learning_rate: 1.0000e-04
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 102s 68ms/step - accuracy: 0.7566 - loss: 0.7033 - val_accuracy: 0.7777 - val_loss: 0.6514 - learning_rate: 1.0000e-04
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 102s 68ms/step - accuracy: 0.7779 - loss: 0.6414 - val_accuracy: 0.7848 - val_loss: 0.6282 - learning_rate: 1.0000e-04
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 101s 68ms/step - accuracy: 0.7959 - loss: 0.5848 - val_accuracy: 0.8057 - val_loss: 0.5750 - learning_rate: 1.0000e-04
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 102s 68ms/step - accuracy: 0.8082 - loss: 0.5477 - val_accuracy: 0.7993 - val_loss: 0.5892 - learning_rate: 1.0000e-04
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 102s 68ms/step - accuracy: 0.8236 - loss: 0.5115 - val_accuracy: 0.7993 - val_loss: 0.5974 - learning_rate: 1.0000e-04
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 102s 68ms/step - accuracy: 0.8349 - loss: 0.4800 - val_accuracy: 0.8211 - val_loss: 0.5421 - learning_rate: 1.0000e-04
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 102s 68ms/step - accuracy: 0.8457 - loss: 0.4510 - val_accuracy: 0.8163 - val_loss: 0.5721 - learning_rate: 1.0000e-04
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 102s 68ms/step - accuracy: 0.8532 - loss: 0.4226 - val_accuracy: 0.8207 - val_loss: 0.5537 - learning_rate: 1.0000e-04
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8595 - loss: 0.4024
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 102s 68ms/step - accuracy: 0.8595 - loss: 0.4024 - val_accuracy: 0.8171 - val_loss: 0.5656 - learning_rate: 1.0000e-04
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 102s 68ms/step - accuracy: 0.8922 - loss: 0.3158 - val_accuracy: 0.8379 - val_loss: 0.5199 - learning_rate: 5.0000e-05
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 102s 68ms/step - accuracy: 0.9014 - loss: 0.2787 - val_accuracy: 0.8472 - val_loss: 0.5077 - learning_rate: 5.0000e-05
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9146 - loss: 0.2489
#
# Reached 91% accuracy. Training cancelled at epoch 18.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 101s 68ms/step - accuracy: 0.9146 - loss: 0.2489 - val_accuracy: 0.8398 - val_loss: 0.5355 - learning_rate: 5.0000e-05
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step
# Logged the training metrics...
# Training starting for GoogLeNet with split- 0.8
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 99s 62ms/step - accuracy: 0.1837 - loss: 2.1293 - val_accuracy: 0.2796 - val_loss: 1.8841 - learning_rate: 1.0000e-04
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 93s 62ms/step - accuracy: 0.2928 - loss: 1.8762 - val_accuracy: 0.3827 - val_loss: 1.6523 - learning_rate: 1.0000e-04
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 93s 62ms/step - accuracy: 0.3623 - loss: 1.7044 - val_accuracy: 0.4207 - val_loss: 1.5882 - learning_rate: 1.0000e-04
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 93s 62ms/step - accuracy: 0.4107 - loss: 1.6074 - val_accuracy: 0.4442 - val_loss: 1.4983 - learning_rate: 1.0000e-04
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 93s 62ms/step - accuracy: 0.4334 - loss: 1.5495 - val_accuracy: 0.4705 - val_loss: 1.4446 - learning_rate: 1.0000e-04
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 94s 62ms/step - accuracy: 0.4544 - loss: 1.5003 - val_accuracy: 0.4939 - val_loss: 1.4130 - learning_rate: 1.0000e-04
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 94s 63ms/step - accuracy: 0.4654 - loss: 1.4684 - val_accuracy: 0.5165 - val_loss: 1.3213 - learning_rate: 1.0000e-04
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 94s 63ms/step - accuracy: 0.4834 - loss: 1.4359 - val_accuracy: 0.5211 - val_loss: 1.3227 - learning_rate: 1.0000e-04
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 93s 62ms/step - accuracy: 0.4969 - loss: 1.4063 - val_accuracy: 0.5307 - val_loss: 1.3093 - learning_rate: 1.0000e-04
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 93s 62ms/step - accuracy: 0.5054 - loss: 1.3771 - val_accuracy: 0.5399 - val_loss: 1.3054 - learning_rate: 1.0000e-04
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 92s 62ms/step - accuracy: 0.5208 - loss: 1.3388 - val_accuracy: 0.5447 - val_loss: 1.2570 - learning_rate: 1.0000e-04
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 93s 62ms/step - accuracy: 0.5293 - loss: 1.3160 - val_accuracy: 0.5508 - val_loss: 1.2581 - learning_rate: 1.0000e-04
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 94s 63ms/step - accuracy: 0.5404 - loss: 1.2944 - val_accuracy: 0.5511 - val_loss: 1.2913 - learning_rate: 1.0000e-04
# Epoch 14/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 94s 63ms/step - accuracy: 0.5454 - loss: 1.2758 - val_accuracy: 0.5648 - val_loss: 1.1916 - learning_rate: 1.0000e-04
# Epoch 15/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 94s 62ms/step - accuracy: 0.5521 - loss: 1.2620 - val_accuracy: 0.5846 - val_loss: 1.1737 - learning_rate: 1.0000e-04
# Epoch 16/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 93s 62ms/step - accuracy: 0.5601 - loss: 1.2336 - val_accuracy: 0.5871 - val_loss: 1.1595 - learning_rate: 1.0000e-04
# Epoch 17/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 93s 62ms/step - accuracy: 0.5693 - loss: 1.2069 - val_accuracy: 0.6202 - val_loss: 1.0773 - learning_rate: 1.0000e-04
# Epoch 18/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 93s 62ms/step - accuracy: 0.5772 - loss: 1.1902 - val_accuracy: 0.6012 - val_loss: 1.1366 - learning_rate: 1.0000e-04
# Epoch 19/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 92s 62ms/step - accuracy: 0.5830 - loss: 1.1747 - val_accuracy: 0.6053 - val_loss: 1.1117 - learning_rate: 1.0000e-04
# Epoch 20/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 94s 62ms/step - accuracy: 0.5879 - loss: 1.1557 - val_accuracy: 0.6273 - val_loss: 1.0579 - learning_rate: 1.0000e-04
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step
# Logged the training metrics...
# Training starting for RNN with split- 0.8
# Epoch 1/15
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 36s 23ms/step - accuracy: 0.2215 - loss: 2.0994 - val_accuracy: 0.3332 - val_loss: 1.8084 - learning_rate: 1.0000e-04
# Epoch 2/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 35s 23ms/step - accuracy: 0.3415 - loss: 1.7983 - val_accuracy: 0.3853 - val_loss: 1.7092 - learning_rate: 1.0000e-04
# Epoch 3/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 34s 23ms/step - accuracy: 0.3750 - loss: 1.7128 - val_accuracy: 0.4099 - val_loss: 1.6281 - learning_rate: 1.0000e-04
# Epoch 4/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 34s 23ms/step - accuracy: 0.4022 - loss: 1.6479 - val_accuracy: 0.4334 - val_loss: 1.5651 - learning_rate: 1.0000e-04
# Epoch 5/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 33s 22ms/step - accuracy: 0.4267 - loss: 1.5877 - val_accuracy: 0.4559 - val_loss: 1.5169 - learning_rate: 1.0000e-04
# Epoch 6/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 34s 23ms/step - accuracy: 0.4445 - loss: 1.5478 - val_accuracy: 0.4667 - val_loss: 1.4823 - learning_rate: 1.0000e-04
# Epoch 7/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 33s 22ms/step - accuracy: 0.4552 - loss: 1.5113 - val_accuracy: 0.4776 - val_loss: 1.4609 - learning_rate: 1.0000e-04
# Epoch 8/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 43s 23ms/step - accuracy: 0.4640 - loss: 1.4888 - val_accuracy: 0.4789 - val_loss: 1.4435 - learning_rate: 1.0000e-04
# Epoch 9/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 42s 23ms/step - accuracy: 0.4718 - loss: 1.4685 - val_accuracy: 0.4952 - val_loss: 1.4067 - learning_rate: 1.0000e-04
# Epoch 10/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 34s 22ms/step - accuracy: 0.4827 - loss: 1.4425 - val_accuracy: 0.5013 - val_loss: 1.3890 - learning_rate: 1.0000e-04
# Epoch 11/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 35s 23ms/step - accuracy: 0.4893 - loss: 1.4090 - val_accuracy: 0.5074 - val_loss: 1.3810 - learning_rate: 1.0000e-04
# Epoch 12/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 34s 22ms/step - accuracy: 0.4949 - loss: 1.4024 - val_accuracy: 0.5128 - val_loss: 1.3596 - learning_rate: 1.0000e-04
# Epoch 13/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 32s 22ms/step - accuracy: 0.5037 - loss: 1.3809 - val_accuracy: 0.5167 - val_loss: 1.3500 - learning_rate: 1.0000e-04
# Epoch 14/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 33s 22ms/step - accuracy: 0.5055 - loss: 1.3673 - val_accuracy: 0.5207 - val_loss: 1.3377 - learning_rate: 1.0000e-04
# Epoch 15/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 33s 22ms/step - accuracy: 0.5172 - loss: 1.3502 - val_accuracy: 0.5214 - val_loss: 1.3307 - learning_rate: 1.0000e-04
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Logged the training metrics...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training starting for CNN with split- 0.8
# Epoch 1/15
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 51s 25ms/step - accuracy: 0.3089 - loss: 1.9781 - val_accuracy: 0.4912 - val_loss: 1.4045 - learning_rate: 1.0000e-04
# Epoch 2/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 36s 24ms/step - accuracy: 0.4761 - loss: 1.4614 - val_accuracy: 0.5599 - val_loss: 1.2183 - learning_rate: 1.0000e-04
# Epoch 3/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 37s 25ms/step - accuracy: 0.5425 - loss: 1.2818 - val_accuracy: 0.6075 - val_loss: 1.0883 - learning_rate: 1.0000e-04
# Epoch 4/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 38s 25ms/step - accuracy: 0.5924 - loss: 1.1536 - val_accuracy: 0.6303 - val_loss: 1.0418 - learning_rate: 1.0000e-04
# Epoch 5/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 37s 25ms/step - accuracy: 0.6355 - loss: 1.0384 - val_accuracy: 0.6719 - val_loss: 0.9294 - learning_rate: 1.0000e-04
# Epoch 6/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 37s 24ms/step - accuracy: 0.6585 - loss: 0.9758 - val_accuracy: 0.6712 - val_loss: 0.9582 - learning_rate: 1.0000e-04
# Epoch 7/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 37s 24ms/step - accuracy: 0.6883 - loss: 0.8966 - val_accuracy: 0.6956 - val_loss: 0.9249 - learning_rate: 1.0000e-04
# Epoch 8/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 37s 24ms/step - accuracy: 0.7142 - loss: 0.8298 - val_accuracy: 0.7519 - val_loss: 0.7114 - learning_rate: 1.0000e-04
# Epoch 9/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 37s 25ms/step - accuracy: 0.7259 - loss: 0.7915 - val_accuracy: 0.7595 - val_loss: 0.6957 - learning_rate: 1.0000e-04
# Epoch 10/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 37s 24ms/step - accuracy: 0.7463 - loss: 0.7364 - val_accuracy: 0.7687 - val_loss: 0.6591 - learning_rate: 1.0000e-04
# Epoch 11/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 37s 25ms/step - accuracy: 0.7583 - loss: 0.7090 - val_accuracy: 0.7343 - val_loss: 0.7994 - learning_rate: 1.0000e-04
# Epoch 12/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 37s 25ms/step - accuracy: 0.7685 - loss: 0.6713 - val_accuracy: 0.7962 - val_loss: 0.5957 - learning_rate: 1.0000e-04
# Epoch 13/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 37s 25ms/step - accuracy: 0.7767 - loss: 0.6507 - val_accuracy: 0.7983 - val_loss: 0.5817 - learning_rate: 1.0000e-04
# Epoch 14/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 37s 24ms/step - accuracy: 0.7849 - loss: 0.6265 - val_accuracy: 0.8112 - val_loss: 0.5547 - learning_rate: 1.0000e-04
# Epoch 15/15
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 37s 24ms/step - accuracy: 0.8010 - loss: 0.5890 - val_accuracy: 0.8091 - val_loss: 0.5627 - learning_rate: 1.0000e-04
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Logged the training metrics...
# Training starting for VGG16 with split- 0.9
# Epoch 1/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 420s 247ms/step - accuracy: 0.1014 - loss: 2.3066 - val_accuracy: 0.0927 - val_loss: 2.3027 - learning_rate: 1.0000e-04
# Epoch 2/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 395s 234ms/step - accuracy: 0.1016 - loss: 2.3026 - val_accuracy: 0.0927 - val_loss: 2.3027 - learning_rate: 1.0000e-04
# Epoch 3/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 394s 234ms/step - accuracy: 0.0988 - loss: 2.3026 - val_accuracy: 0.0927 - val_loss: 2.3027 - learning_rate: 1.0000e-04
# Epoch 4/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.0984 - loss: 2.3026
# Epoch 4: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 395s 234ms/step - accuracy: 0.0984 - loss: 2.3026 - val_accuracy: 0.0927 - val_loss: 2.3027 - learning_rate: 1.0000e-04
# Epoch 5/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 394s 234ms/step - accuracy: 0.1016 - loss: 2.3026 - val_accuracy: 0.0927 - val_loss: 2.3027 - learning_rate: 5.0000e-05
# Epoch 6/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 394s 234ms/step - accuracy: 0.0986 - loss: 2.3026 - val_accuracy: 0.0927 - val_loss: 2.3027 - learning_rate: 5.0000e-05
# Epoch 7/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.0998 - loss: 2.3026
# Epoch 7: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 394s 233ms/step - accuracy: 0.0998 - loss: 2.3026 - val_accuracy: 0.0927 - val_loss: 2.3027 - learning_rate: 5.0000e-05
# Epoch 8/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 394s 234ms/step - accuracy: 0.1004 - loss: 2.3026 - val_accuracy: 0.0927 - val_loss: 2.3027 - learning_rate: 2.5000e-05
# Epoch 9/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 394s 233ms/step - accuracy: 0.1005 - loss: 2.3026 - val_accuracy: 0.0927 - val_loss: 2.3027 - learning_rate: 2.5000e-05
# Epoch 10/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.1022 - loss: 2.3025
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 394s 234ms/step - accuracy: 0.1022 - loss: 2.3025 - val_accuracy: 0.0927 - val_loss: 2.3027 - learning_rate: 2.5000e-05
# Epoch 10: early stopping
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 24s 124ms/step
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 23s 124ms/step
# Logged the training metrics...
# Training starting for AlexNet with split- 0.9
# Epoch 1/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 115s 66ms/step - accuracy: 0.3043 - loss: 1.8676 - val_accuracy: 0.5203 - val_loss: 1.3306 - learning_rate: 1.0000e-04
# Epoch 2/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 111s 66ms/step - accuracy: 0.5383 - loss: 1.2853 - val_accuracy: 0.6215 - val_loss: 1.0729 - learning_rate: 1.0000e-04
# Epoch 3/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 111s 66ms/step - accuracy: 0.6272 - loss: 1.0550 - val_accuracy: 0.6950 - val_loss: 0.8713 - learning_rate: 1.0000e-04
# Epoch 4/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 111s 66ms/step - accuracy: 0.6846 - loss: 0.8963 - val_accuracy: 0.7435 - val_loss: 0.7381 - learning_rate: 1.0000e-04
# Epoch 5/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 111s 66ms/step - accuracy: 0.7178 - loss: 0.8005 - val_accuracy: 0.7538 - val_loss: 0.7073 - learning_rate: 1.0000e-04
# Epoch 6/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 111s 66ms/step - accuracy: 0.7501 - loss: 0.7186 - val_accuracy: 0.7677 - val_loss: 0.6870 - learning_rate: 1.0000e-04
# Epoch 7/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 111s 66ms/step - accuracy: 0.7693 - loss: 0.6682 - val_accuracy: 0.7993 - val_loss: 0.5847 - learning_rate: 1.0000e-04
# Epoch 8/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 112s 66ms/step - accuracy: 0.7899 - loss: 0.6087 - val_accuracy: 0.8102 - val_loss: 0.5529 - learning_rate: 1.0000e-04
# Epoch 9/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 112s 66ms/step - accuracy: 0.8075 - loss: 0.5593 - val_accuracy: 0.8068 - val_loss: 0.5682 - learning_rate: 1.0000e-04
# Epoch 10/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 111s 66ms/step - accuracy: 0.8191 - loss: 0.5270 - val_accuracy: 0.8188 - val_loss: 0.5464 - learning_rate: 1.0000e-04
# Epoch 11/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 111s 66ms/step - accuracy: 0.8306 - loss: 0.4891 - val_accuracy: 0.8262 - val_loss: 0.5211 - learning_rate: 1.0000e-04
# Epoch 12/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 111s 66ms/step - accuracy: 0.8436 - loss: 0.4467 - val_accuracy: 0.8255 - val_loss: 0.5246 - learning_rate: 1.0000e-04
# Epoch 13/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 111s 66ms/step - accuracy: 0.8542 - loss: 0.4215 - val_accuracy: 0.8253 - val_loss: 0.5451 - learning_rate: 1.0000e-04
# Epoch 14/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 111s 66ms/step - accuracy: 0.8614 - loss: 0.3986 - val_accuracy: 0.8433 - val_loss: 0.4959 - learning_rate: 1.0000e-04
# Epoch 15/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 111s 66ms/step - accuracy: 0.8733 - loss: 0.3714 - val_accuracy: 0.8365 - val_loss: 0.4912 - learning_rate: 1.0000e-04
# Epoch 16/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 111s 66ms/step - accuracy: 0.8769 - loss: 0.3527 - val_accuracy: 0.8320 - val_loss: 0.5606 - learning_rate: 1.0000e-04
# Epoch 17/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 111s 66ms/step - accuracy: 0.8840 - loss: 0.3372 - val_accuracy: 0.8497 - val_loss: 0.4841 - learning_rate: 1.0000e-04
# Epoch 18/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 111s 66ms/step - accuracy: 0.8928 - loss: 0.3132 - val_accuracy: 0.8418 - val_loss: 0.5291 - learning_rate: 1.0000e-04
# Epoch 19/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 111s 66ms/step - accuracy: 0.8965 - loss: 0.3014 - val_accuracy: 0.8460 - val_loss: 0.5128 - learning_rate: 1.0000e-04
# Epoch 20/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9047 - loss: 0.2772
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 111s 66ms/step - accuracy: 0.9047 - loss: 0.2772 - val_accuracy: 0.8493 - val_loss: 0.5141 - learning_rate: 1.0000e-04
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step
# Logged the training metrics...
# Training starting for GoogLeNet with split- 0.9
# Epoch 1/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 106s 60ms/step - accuracy: 0.1864 - loss: 2.1232 - val_accuracy: 0.3327 - val_loss: 1.8119 - learning_rate: 1.0000e-04
# Epoch 2/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 100s 59ms/step - accuracy: 0.3106 - loss: 1.8443 - val_accuracy: 0.3922 - val_loss: 1.6750 - learning_rate: 1.0000e-04
# Epoch 3/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 100s 59ms/step - accuracy: 0.3743 - loss: 1.6942 - val_accuracy: 0.4273 - val_loss: 1.5352 - learning_rate: 1.0000e-04
# Epoch 4/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 101s 60ms/step - accuracy: 0.4059 - loss: 1.6109 - val_accuracy: 0.4233 - val_loss: 1.5521 - learning_rate: 1.0000e-04
# Epoch 5/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 100s 60ms/step - accuracy: 0.4329 - loss: 1.5517 - val_accuracy: 0.4633 - val_loss: 1.4664 - learning_rate: 1.0000e-04
# Epoch 6/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 100s 60ms/step - accuracy: 0.4571 - loss: 1.4991 - val_accuracy: 0.4717 - val_loss: 1.4172 - learning_rate: 1.0000e-04
# Epoch 7/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 100s 59ms/step - accuracy: 0.4756 - loss: 1.4519 - val_accuracy: 0.4902 - val_loss: 1.4142 - learning_rate: 1.0000e-04
# Epoch 8/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 100s 59ms/step - accuracy: 0.4876 - loss: 1.4223 - val_accuracy: 0.5125 - val_loss: 1.3336 - learning_rate: 1.0000e-04
# Epoch 9/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 101s 60ms/step - accuracy: 0.4994 - loss: 1.3860 - val_accuracy: 0.5328 - val_loss: 1.2994 - learning_rate: 1.0000e-04
# Epoch 10/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 100s 59ms/step - accuracy: 0.5139 - loss: 1.3545 - val_accuracy: 0.5207 - val_loss: 1.3467 - learning_rate: 1.0000e-04
# Epoch 11/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 100s 59ms/step - accuracy: 0.5235 - loss: 1.3285 - val_accuracy: 0.5228 - val_loss: 1.3167 - learning_rate: 1.0000e-04
# Epoch 12/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 101s 60ms/step - accuracy: 0.5327 - loss: 1.3045 - val_accuracy: 0.5628 - val_loss: 1.2061 - learning_rate: 1.0000e-04
# Epoch 13/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 100s 59ms/step - accuracy: 0.5421 - loss: 1.2754 - val_accuracy: 0.5625 - val_loss: 1.2383 - learning_rate: 1.0000e-04
# Epoch 14/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 100s 59ms/step - accuracy: 0.5518 - loss: 1.2523 - val_accuracy: 0.5693 - val_loss: 1.2115 - learning_rate: 1.0000e-04
# Epoch 15/20
# 1687/1688 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5570 - loss: 1.2433
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 100s 60ms/step - accuracy: 0.5570 - loss: 1.2433 - val_accuracy: 0.5545 - val_loss: 1.2727 - learning_rate: 1.0000e-04
# Epoch 16/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 101s 60ms/step - accuracy: 0.5836 - loss: 1.1846 - val_accuracy: 0.5885 - val_loss: 1.1400 - learning_rate: 5.0000e-05
# Epoch 17/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 101s 60ms/step - accuracy: 0.5793 - loss: 1.1771 - val_accuracy: 0.5905 - val_loss: 1.1545 - learning_rate: 5.0000e-05
# Epoch 18/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 100s 59ms/step - accuracy: 0.5860 - loss: 1.1611 - val_accuracy: 0.5803 - val_loss: 1.2038 - learning_rate: 5.0000e-05
# Epoch 19/20
# 1687/1688 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.5898 - loss: 1.1524
# Epoch 19: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 142s 60ms/step - accuracy: 0.5898 - loss: 1.1524 - val_accuracy: 0.5952 - val_loss: 1.1404 - learning_rate: 5.0000e-05
# Epoch 20/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 100s 59ms/step - accuracy: 0.6039 - loss: 1.1125 - val_accuracy: 0.6207 - val_loss: 1.0640 - learning_rate: 2.5000e-05
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step
# Logged the training metrics...
# Training starting for RNN with split- 0.9
# Epoch 1/15
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 39s 22ms/step - accuracy: 0.2315 - loss: 2.0826 - val_accuracy: 0.3347 - val_loss: 1.7989 - learning_rate: 1.0000e-04
# Epoch 2/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 36s 22ms/step - accuracy: 0.3495 - loss: 1.7703 - val_accuracy: 0.3882 - val_loss: 1.6861 - learning_rate: 1.0000e-04
# Epoch 3/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 37s 22ms/step - accuracy: 0.3823 - loss: 1.6931 - val_accuracy: 0.4098 - val_loss: 1.6147 - learning_rate: 1.0000e-04
# Epoch 4/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 37s 22ms/step - accuracy: 0.4158 - loss: 1.6149 - val_accuracy: 0.4398 - val_loss: 1.5323 - learning_rate: 1.0000e-04
# Epoch 5/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 37s 22ms/step - accuracy: 0.4337 - loss: 1.5612 - val_accuracy: 0.4553 - val_loss: 1.4891 - learning_rate: 1.0000e-04
# Epoch 6/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 37s 22ms/step - accuracy: 0.4517 - loss: 1.5210 - val_accuracy: 0.4663 - val_loss: 1.4682 - learning_rate: 1.0000e-04
# Epoch 7/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 36s 22ms/step - accuracy: 0.4649 - loss: 1.4907 - val_accuracy: 0.4690 - val_loss: 1.4520 - learning_rate: 1.0000e-04
# Epoch 8/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 38s 22ms/step - accuracy: 0.4746 - loss: 1.4622 - val_accuracy: 0.4860 - val_loss: 1.4130 - learning_rate: 1.0000e-04
# Epoch 9/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 36s 21ms/step - accuracy: 0.4870 - loss: 1.4279 - val_accuracy: 0.4993 - val_loss: 1.3944 - learning_rate: 1.0000e-04
# Epoch 10/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 37s 22ms/step - accuracy: 0.4924 - loss: 1.4167 - val_accuracy: 0.5068 - val_loss: 1.3734 - learning_rate: 1.0000e-04
# Epoch 11/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 37s 22ms/step - accuracy: 0.4986 - loss: 1.3939 - val_accuracy: 0.5205 - val_loss: 1.3406 - learning_rate: 1.0000e-04
# Epoch 12/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 37s 22ms/step - accuracy: 0.5109 - loss: 1.3786 - val_accuracy: 0.5327 - val_loss: 1.3132 - learning_rate: 1.0000e-04
# Epoch 13/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 38s 22ms/step - accuracy: 0.5161 - loss: 1.3518 - val_accuracy: 0.5282 - val_loss: 1.2978 - learning_rate: 1.0000e-04
# Epoch 14/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 37s 22ms/step - accuracy: 0.5215 - loss: 1.3342 - val_accuracy: 0.5273 - val_loss: 1.3066 - learning_rate: 1.0000e-04
# Epoch 15/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 38s 22ms/step - accuracy: 0.5245 - loss: 1.3239 - val_accuracy: 0.5340 - val_loss: 1.2807 - learning_rate: 1.0000e-04
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Logged the training metrics...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training starting for CNN with split- 0.9
# Epoch 1/15
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 61s 29ms/step - accuracy: 0.3157 - loss: 1.9525 - val_accuracy: 0.4992 - val_loss: 1.4181 - learning_rate: 1.0000e-04
# Epoch 2/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 40s 23ms/step - accuracy: 0.4930 - loss: 1.4127 - val_accuracy: 0.5540 - val_loss: 1.2502 - learning_rate: 1.0000e-04
# Epoch 3/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 42s 25ms/step - accuracy: 0.5533 - loss: 1.2502 - val_accuracy: 0.6230 - val_loss: 1.0652 - learning_rate: 1.0000e-04
# Epoch 4/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 41s 24ms/step - accuracy: 0.6124 - loss: 1.1099 - val_accuracy: 0.6667 - val_loss: 0.9313 - learning_rate: 1.0000e-04
# Epoch 5/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 41s 24ms/step - accuracy: 0.6519 - loss: 1.0023 - val_accuracy: 0.7020 - val_loss: 0.8513 - learning_rate: 1.0000e-04
# Epoch 6/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 40s 24ms/step - accuracy: 0.6795 - loss: 0.9200 - val_accuracy: 0.7032 - val_loss: 0.8609 - learning_rate: 1.0000e-04
# Epoch 7/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 41s 24ms/step - accuracy: 0.7034 - loss: 0.8581 - val_accuracy: 0.7367 - val_loss: 0.7502 - learning_rate: 1.0000e-04
# Epoch 8/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 41s 24ms/step - accuracy: 0.7181 - loss: 0.8117 - val_accuracy: 0.7570 - val_loss: 0.6782 - learning_rate: 1.0000e-04
# Epoch 9/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 40s 24ms/step - accuracy: 0.7357 - loss: 0.7650 - val_accuracy: 0.7610 - val_loss: 0.6933 - learning_rate: 1.0000e-04
# Epoch 10/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 40s 24ms/step - accuracy: 0.7545 - loss: 0.7151 - val_accuracy: 0.7873 - val_loss: 0.6201 - learning_rate: 1.0000e-04
# Epoch 11/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 40s 24ms/step - accuracy: 0.7669 - loss: 0.6758 - val_accuracy: 0.7960 - val_loss: 0.6079 - learning_rate: 1.0000e-04
# Epoch 12/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 40s 24ms/step - accuracy: 0.7767 - loss: 0.6451 - val_accuracy: 0.7880 - val_loss: 0.6233 - learning_rate: 1.0000e-04
# Epoch 13/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 40s 24ms/step - accuracy: 0.7891 - loss: 0.6175 - val_accuracy: 0.8110 - val_loss: 0.5617 - learning_rate: 1.0000e-04
# Epoch 14/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 41s 24ms/step - accuracy: 0.7999 - loss: 0.5819 - val_accuracy: 0.7865 - val_loss: 0.6248 - learning_rate: 1.0000e-04
# Epoch 15/15
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 41s 24ms/step - accuracy: 0.8007 - loss: 0.5788 - val_accuracy: 0.8095 - val_loss: 0.5809 - learning_rate: 1.0000e-04
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Logged the training metrics...
# CPU times: user 1h 45min 24s, sys: 11min, total: 1h 56min 24s
# Wall time: 5h 19min

# %%
print(df_cifar)
# Out:
#   DatasetName      Model  Split  Accuracy  Val_Accuracy
# 0     cifar10      VGG16    0.8  0.926146      0.901250
# 1     cifar10    AlexNet    0.8  0.911375      0.839833
# 2     cifar10  GoogLeNet    0.8  0.587667      0.627250
# 3     cifar10        RNN    0.8  0.515521      0.521417
# 4     cifar10        CNN    0.8  0.799979      0.809083
# 5     cifar10      VGG16    0.9  0.101111      0.092667
# 6     cifar10    AlexNet    0.9  0.900981      0.849333
# 7     cifar10  GoogLeNet    0.9  0.600852      0.620667
# 8     cifar10        RNN    0.9  0.528037      0.534000
# 9     cifar10        CNN    0.9  0.802870      0.809500

# %%
plot_plots("cifar10", 'results/plots')

# %%
#df_mnist= run_experiment("mnist")

# %%
#print(df_mnist)

# %%
#plot_plots("cifar10", 'results/plots')

# %%
#df_all= pd.concat([df_cifar, df_mnist], axis=0)
#print(df_all)
